# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

iris= pd.read_csv("iris.csv")

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#how many data points for each class are present

iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # 2D SCATTER PLOT

# %%
iris.plot(kind='scatter' ,x='sepal_length', y='sepal_width')
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) \
    .map(plt.scatter, "sepal_length" ,"sepal_width")  \
    .add_legend();
plt.show()

# %% [markdown]
# # PAIR_PLOT

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris ,hue="species", height=3);
plt.show()

# %%
x=int(input("enter the petal_width  "))
y=int(input("enter the petal_lenth  "))
# Out:
# enter the petal_width  1
# enter the petal_lenth  2

# %%
if(y<=2 and x<=1):
    print("setosa")
elif(x>=1 and x<=2 and y<5 and y>=2.5):
    print("versicolor")
elif(x>=2 and y>=5 and y<=7 and x<=3 ):
    print("virginica")
else:
    print("size is not supported")
# Out:
# setosa

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
plt.show();
# Out:
# C:\Users\Bhanu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Bhanu\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # MEAN, VARIANCE AND STANDARD DEVIATION

# %%
print("means :")
print(np.mean(iris_setosa["petal_length"]))
#mean with an outlier
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\n STD");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# means :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 print("means :")
# ----> 2 print(np.mean(iris_setosa["petal_length"]))
#       3 #mean with an outlier
#       4 print(np.mean(np.append(iris_setosa["petal_length"],50)));
#
# NameError: name 'iris_setosa' is not defined

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.violinplot(x='species',y='petal_length', data=iris, size=8)
plt.show()

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# # Univariate, bivariate nd multivariate

# %%
sns.jointplot(x='species',y='petal_length', data=iris_setosa, kind="kde");
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.jointplot(x='species',y='petal_length', data=iris_setosa, kind="kde");
#       2 plt.show();
#
# NameError: name 'iris_setosa' is not defined

# %% [markdown]
# # Cumulative Distribution Function

# %%
counts, bin_edges = np.histogram(iris_)
